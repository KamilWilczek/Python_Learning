# %%
import pandas as pd
import numpy as np

# %%
url = 'https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=data%2Favia_par_pl.tsv.gz'

# %%
pd.read_csv(url,delimiter='\t')
# Out:
#            unit,tra_meas,airp_pr\time 2019Q2  2019Q1  2019M06  2019M05   \
# 0      FLIGHT,CAF_PAS,PL_EPBY_DE_EDDF    182     174       60       62
# 1      FLIGHT,CAF_PAS,PL_EPBY_DE_EDLV      :       :        :        :
# 2      FLIGHT,CAF_PAS,PL_EPBY_ES_LEGE      :       :        :        :
# 3      FLIGHT,CAF_PAS,PL_EPBY_IE_EIDW     52      56       16       18
# 4      FLIGHT,CAF_PAS,PL_EPBY_PL_EPWA      :       :        :        :
# ...                               ...     ...     ...      ...      ...
# 6064  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGNX   9828   10017     3213     3402
# 6065  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGPF      :       :        :        :
# 6066  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGPH      :       :        :        :
# 6067  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGPK      :       :        :        :
# 6068  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGSS  30051   26838     9828    10017
#
#      2019M04  2019M03  2019M02  2019M01  2018Q4   ... 2004M09  2004M08   \
# ...

# %%
routes = pd.read_csv(url,delimiter='\t')

# %%
routes.head()
# Out:
#        unit,tra_meas,airp_pr\time 2019Q2  2019Q1  2019M06  2019M05  2019M04   \
# 0  FLIGHT,CAF_PAS,PL_EPBY_DE_EDDF    182     174       60       62       60
# 1  FLIGHT,CAF_PAS,PL_EPBY_DE_EDLV      :       :        :        :        :
# 2  FLIGHT,CAF_PAS,PL_EPBY_ES_LEGE      :       :        :        :        :
# 3  FLIGHT,CAF_PAS,PL_EPBY_IE_EIDW     52      56       16       18       18
# 4  FLIGHT,CAF_PAS,PL_EPBY_PL_EPWA      :       :        :        :        :
#
#   2019M03  2019M02  2019M01  2018Q4   ... 2004M09  2004M08  2004M07  2004M06   \
# 0      60       54       60     170   ...       :        :        :        :
# 1       :        :        :      36   ...       :        :        :        :
# 2       :        :        :       :   ...       :        :        :        :
# 3      18       16       22      56   ...       :        :        :        :
# 4       :        :        :       :   ...       :        :        :        :
#
# ...

# %%
routes['unit,tra_meas,airp_pr\\time'].str.split(',')
# Out:
# 0        [FLIGHT, CAF_PAS, PL_EPBY_DE_EDDF]
# 1        [FLIGHT, CAF_PAS, PL_EPBY_DE_EDLV]
# 2        [FLIGHT, CAF_PAS, PL_EPBY_ES_LEGE]
# 3        [FLIGHT, CAF_PAS, PL_EPBY_IE_EIDW]
# 4        [FLIGHT, CAF_PAS, PL_EPBY_PL_EPWA]
#                        ...
# 6064    [SEAT, ST_PAS_DEP, PL_EPWR_UK_EGNX]
# 6065    [SEAT, ST_PAS_DEP, PL_EPWR_UK_EGPF]
# 6066    [SEAT, ST_PAS_DEP, PL_EPWR_UK_EGPH]
# 6067    [SEAT, ST_PAS_DEP, PL_EPWR_UK_EGPK]
# 6068    [SEAT, ST_PAS_DEP, PL_EPWR_UK_EGSS]
# Name: unit,tra_meas,airp_pr\time, Length: 6069, dtype: object

# %%
routes['unit,tra_meas,airp_pr\\time'].str.split(',',expand=True)
# Out:
#            0           1                2
# 0     FLIGHT     CAF_PAS  PL_EPBY_DE_EDDF
# 1     FLIGHT     CAF_PAS  PL_EPBY_DE_EDLV
# 2     FLIGHT     CAF_PAS  PL_EPBY_ES_LEGE
# 3     FLIGHT     CAF_PAS  PL_EPBY_IE_EIDW
# 4     FLIGHT     CAF_PAS  PL_EPBY_PL_EPWA
# ...      ...         ...              ...
# 6064    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGNX
# 6065    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGPF
# 6066    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGPH
# 6067    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGPK
# 6068    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGSS
#
# [6069 rows x 3 columns]

# %%
routes_desc = routes['unit,tra_meas,airp_pr\\time'].str.split(',',expand=True)

# %%
routes_desc.rename({0:'unit',1:'tra_meas',2:'airport'}, axis=1,inplace=True)

# %%
routes_desc.head()
# Out:
#      unit tra_meas          airport
# 0  FLIGHT  CAF_PAS  PL_EPBY_DE_EDDF
# 1  FLIGHT  CAF_PAS  PL_EPBY_DE_EDLV
# 2  FLIGHT  CAF_PAS  PL_EPBY_ES_LEGE
# 3  FLIGHT  CAF_PAS  PL_EPBY_IE_EIDW
# 4  FLIGHT  CAF_PAS  PL_EPBY_PL_EPWA

# %%
routes_desc.join(routes)
# Out:
#         unit    tra_meas          airport       unit,tra_meas,airp_pr\time  \
# 0     FLIGHT     CAF_PAS  PL_EPBY_DE_EDDF   FLIGHT,CAF_PAS,PL_EPBY_DE_EDDF
# 1     FLIGHT     CAF_PAS  PL_EPBY_DE_EDLV   FLIGHT,CAF_PAS,PL_EPBY_DE_EDLV
# 2     FLIGHT     CAF_PAS  PL_EPBY_ES_LEGE   FLIGHT,CAF_PAS,PL_EPBY_ES_LEGE
# 3     FLIGHT     CAF_PAS  PL_EPBY_IE_EIDW   FLIGHT,CAF_PAS,PL_EPBY_IE_EIDW
# 4     FLIGHT     CAF_PAS  PL_EPBY_PL_EPWA   FLIGHT,CAF_PAS,PL_EPBY_PL_EPWA
# ...      ...         ...              ...                              ...
# 6064    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGNX  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGNX
# 6065    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGPF  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGPF
# 6066    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGPH  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGPH
# 6067    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGPK  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGPK
# 6068    SEAT  ST_PAS_DEP  PL_EPWR_UK_EGSS  SEAT,ST_PAS_DEP,PL_EPWR_UK_EGSS
#
# ...

# %%
routes_desc = routes_desc.join(routes)

# %%
routes_desc.head()
# Out:
#      unit tra_meas          airport      unit,tra_meas,airp_pr\time 2019Q2   \
# 0  FLIGHT  CAF_PAS  PL_EPBY_DE_EDDF  FLIGHT,CAF_PAS,PL_EPBY_DE_EDDF    182
# 1  FLIGHT  CAF_PAS  PL_EPBY_DE_EDLV  FLIGHT,CAF_PAS,PL_EPBY_DE_EDLV      :
# 2  FLIGHT  CAF_PAS  PL_EPBY_ES_LEGE  FLIGHT,CAF_PAS,PL_EPBY_ES_LEGE      :
# 3  FLIGHT  CAF_PAS  PL_EPBY_IE_EIDW  FLIGHT,CAF_PAS,PL_EPBY_IE_EIDW     52
# 4  FLIGHT  CAF_PAS  PL_EPBY_PL_EPWA  FLIGHT,CAF_PAS,PL_EPBY_PL_EPWA      :
#
#   2019Q1  2019M06  2019M05  2019M04  2019M03   ... 2004M09  2004M08  2004M07   \
# 0    174       60       62       60       60   ...       :        :        :
# 1      :        :        :        :        :   ...       :        :        :
# 2      :        :        :        :        :   ...       :        :        :
# 3     56       16       18       18       18   ...       :        :        :
# 4      :        :        :        :        :   ...       :        :        :
#
# ...

# %%
routes_desc.drop('unit,tra_meas,airp_pr\\time',axis=1,inplace=True)

# %%
routes_desc.head()
# Out:
#      unit tra_meas          airport 2019Q2  2019Q1  2019M06  2019M05   \
# 0  FLIGHT  CAF_PAS  PL_EPBY_DE_EDDF    182     174       60       62
# 1  FLIGHT  CAF_PAS  PL_EPBY_DE_EDLV      :       :        :        :
# 2  FLIGHT  CAF_PAS  PL_EPBY_ES_LEGE      :       :        :        :
# 3  FLIGHT  CAF_PAS  PL_EPBY_IE_EIDW     52      56       16       18
# 4  FLIGHT  CAF_PAS  PL_EPBY_PL_EPWA      :       :        :        :
#
#   2019M04  2019M03  2019M02   ... 2004M09  2004M08  2004M07  2004M06   \
# 0      60       60       54   ...       :        :        :        :
# 1       :        :        :   ...       :        :        :        :
# 2       :        :        :   ...       :        :        :        :
# 3      18       18       16   ...       :        :        :        :
# 4       :        :        :   ...       :        :        :        :
#
#   2004M05  2004M04  2004M03  2004M02  2004M01  2004
# 0       :        :        :        :        :     :
# ...

# %%
json_link = 'http://floatrates.com/daily/chf.json'

# %%
pd.read_json(json_link)
# Out:
#                                       usd                           eur  \
# code                                  USD                           EUR
# alphaCode                             USD                           EUR
# numericCode                           840                           978
# name                          U.S. Dollar                          Euro
# rate                              1.05651                      0.941546
# date         Fri, 6 Mar 2020 07:00:02 GMT  Fri, 6 Mar 2020 07:00:02 GMT
# inverseRate                      0.946511                       1.06208
#
#                                       gbp                           aud  \
# code                                  GBP                           AUD
# alphaCode                             GBP                           AUD
# numericCode                           826                           036
# name                  U.K. Pound Sterling             Australian Dollar
# ...

# %%
pd.read_json(json_link).transpose()
# Out:
#     code alphaCode numericCode                    name      rate  \
# usd  USD       USD         840             U.S. Dollar   1.05651
# eur  EUR       EUR         978                    Euro  0.941546
# gbp  GBP       GBP         826     U.K. Pound Sterling  0.816357
# aud  AUD       AUD         036       Australian Dollar   1.59931
# cad  CAD       CAD         124         Canadian Dollar   1.41668
# ..   ...       ...         ...                     ...       ...
# kes  KES       KES         404         Kenyan shilling   108.323
# dkk  DKK       DKK         208            Danish Krone   7.05804
# aed  AED       AED         784            U.A.E Dirham   3.88017
# xof  XOF       XOF         952  West African CFA Franc   621.386
# uzs  UZS       UZS         860          Uzbekistan Sum   10063.9
#
#                              date inverseRate
# usd  Fri, 6 Mar 2020 07:00:02 GMT    0.946511
# eur  Fri, 6 Mar 2020 07:00:02 GMT     1.06208
# ...

# %%
# importing data
# finding data
# undestanding data
# importing data(technical aspect)
# df.read_*
