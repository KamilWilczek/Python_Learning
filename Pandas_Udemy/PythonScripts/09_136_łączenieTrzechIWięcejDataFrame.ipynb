# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/northwind-mongo-master/products_del_2.csv",
                      usecols=['ProductID','ProductName','CategoryID','UnitPrice'])

# %%
categories = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/northwind-mongo-master/categories1.csv",
                        usecols=['CategoryID','CategoryName','Description'])

# %%
orders = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/northwind-mongo-master/order-details.csv")

# %%
products.head(2)
# Out:
#    ProductID ProductName  CategoryID  UnitPrice
# 0          1        Chai           1       18.0
# 1          2       Chang           1       19.0

# %%
categories.head(2)
# Out:
#    CategoryID CategoryName              Description
# 0           1    Beverages              Soft drinks
# 1           2   Condiments  Sweet and savory sauces

# %%
orders.head(2)
# Out:
#    OrderID  ProductID  UnitPrice  Quantity  Discount
# 0    10248         11       14.0        12       0.0
# 1    10248         42        9.8        10       0.0

# %%
cat_prod = products.merge(categories,on='CategoryID')

# %%
cat_prod.head(2)
# Out:
#    ProductID ProductName  CategoryID  UnitPrice CategoryName  Description
# 0          1        Chai           1       18.0    Beverages  Soft drinks
# 1          2       Chang           1       19.0    Beverages  Soft drinks

# %%
# UnitPrice z products to cena obecna
# UnitPrice z orders to cena po jakiej zostalo sprzedane, wiec moga sie roznic
cat_prod.merge(orders,on='ProductID').head()
# Out:
#    ProductID ProductName  CategoryID  UnitPrice_x CategoryName  Description  \
# 0          1        Chai           1         18.0    Beverages  Soft drinks
# 1          1        Chai           1         18.0    Beverages  Soft drinks
# 2          1        Chai           1         18.0    Beverages  Soft drinks
# 3          1        Chai           1         18.0    Beverages  Soft drinks
# 4          1        Chai           1         18.0    Beverages  Soft drinks
#
#    OrderID  UnitPrice_y  Quantity  Discount
# 0    10285         14.4        45      0.20
# 1    10294         14.4        18      0.00
# 2    10317         14.4        20      0.00
# 3    10348         14.4        15      0.15
# 4    10354         14.4        12      0.00

# %%
cat_prod.merge(orders,on='ProductID',suffixes=['_Prod','_Order']).head()
# Out:
#    ProductID ProductName  CategoryID  UnitPrice_Prod CategoryName  \
# 0          1        Chai           1            18.0    Beverages
# 1          1        Chai           1            18.0    Beverages
# 2          1        Chai           1            18.0    Beverages
# 3          1        Chai           1            18.0    Beverages
# 4          1        Chai           1            18.0    Beverages
#
#    Description  OrderID  UnitPrice_Order  Quantity  Discount
# 0  Soft drinks    10285             14.4        45      0.20
# 1  Soft drinks    10294             14.4        18      0.00
# 2  Soft drinks    10317             14.4        20      0.00
# 3  Soft drinks    10348             14.4        15      0.15
# 4  Soft drinks    10354             14.4        12      0.00

# %%
# merging multiple tables
# df1.merge(df2,...).merge(df3,...)
# suffix=['suffix_left','suffix_right']
