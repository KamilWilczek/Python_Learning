# %%
"""1. Zaimportuj moduł pandas i numpy nadaj im standardowe aliasy"""

import pandas as pd
import numpy as np

# %%
"""2. Do zmiennej mcdonalds zaimportuj plik mcdonalds.csv, pobierz tylko kolumny Category, Item, Calories
i TotalFat"""

mcdonalds = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/mcdonalds.csv",
                       usecols=['Category','Item','Calories','TotalFat'])
mcdonalds.head()
# Out:
#     Category                              Item  Calories  TotalFat
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0

# %%
"""3. Zadeklaruj zmienną excelWriter, która pozwoli na zapisywanie danych do skoroszytu mcdonaldsexcel.xls"""

excelWriter = pd.ExcelWriter('mcdonaldsexcel.xls')

# %%
"""4. Zapisz zawartość zmiennej mcdonalds do excelWriter. Nowy arkusz ma się nazywać Menu. Indeks nie
powinien być zapisywany"""

mcdonalds.to_excel(excelWriter,index=False,sheet_name='Menu')

# %%
"""5. Zapisz excelWriter na dysku. (Dobry pomysł sprawdzić, jak wygląda teraz plik, ale po takim sprawdzeniu
pamiętaj aby zamknąć Excela, bo inaczej dostęp do pliku może być zablokowany)"""

excelWriter.save()

# %%
"""6. Do zmiennej imported1 zaimportuj ze skoroszytu mcdonalds-excel.xls arkusz Menu."""

imported1 = pd.read_excel('mcdonaldsexcel.xls', sheet_name='Menu')
imported1.head()
# Out:
#     Category                              Item  Calories  TotalFat
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0

# %%
"""7. Zaktualizuj w imported zawartość kolumny Calories dzieląc ją przez 2."""

imported1.loc[:,'Calories']/=2

# %%
imported1.head()
# Out:
#     Category                              Item  Calories  TotalFat
# 0  Breakfast                      Egg McMuffin     150.0      13.0
# 1  Breakfast                 Egg White Delight     125.0       8.0
# 2  Breakfast                  Sausage McMuffin     185.0      23.0
# 3  Breakfast         Sausage McMuffin with Egg     225.0      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites     200.0      23.0

# %%
"""8. Zapisz zawartość imported1 w excelWriter, dodając arkusz Menu Light"""

imported1.to_excel(excelWriter, index=False, sheet_name='Menu Light')

# %%
excelWriter.save()

# %%
"""9. Zaktualizuj w imported1 zawartość kolumny Calories dzieląc ją ponownie przez 2."""

imported1.loc[:,'Calories']/=2
imported1.head()
# Out:
#     Category                              Item  Calories  TotalFat
# 0  Breakfast                      Egg McMuffin      75.0      13.0
# 1  Breakfast                 Egg White Delight      62.5       8.0
# 2  Breakfast                  Sausage McMuffin      92.5      23.0
# 3  Breakfast         Sausage McMuffin with Egg     112.5      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites     100.0      23.0

# %%
"""10. Zapisz zawartość imported1 w excelWriter, dodając arkusz Menu Extra Light"""

imported1.to_excel(excelWriter, index=False, sheet_name='Menu Extra Light')
excelWriter.save()

# %%
"""11. Zapisz excelWriter na dysku."""

excelWriter.save()

# %%
"""12. Do zmiennej final wczytaj zawartość wszyskich arkuszy ze skoroszytu mcdonalds-excel.xls"""

final = pd.read_excel('mcdonaldsexcel.xls', sheet_name=[0,1,2])

# %%
final
# Out:
# OrderedDict([(0,
#                              Category                                               Item  \
#               0             Breakfast                                       Egg McMuffin
#               1             Breakfast                                  Egg White Delight
#               2             Breakfast                                   Sausage McMuffin
#               3             Breakfast                          Sausage McMuffin with Egg
#               4             Breakfast                   Sausage McMuffin with Egg Whites
#               ..                  ...                                                ...
#               255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
#               256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
#               257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
#               258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
#               259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                    Calories  TotalFat
#               0         300      13.0
#               1         250       8.0
#               2         370      23.0
#               3         450      28.0
#               4         400      23.0
#               ..        ...       ...
#               255       510      17.0
#               256       690      23.0
#               257       340      11.0
#               258       810      32.0
#               259       410      16.0
#
#               [260 rows x 4 columns]),
#              (1,
#                              Category                                               Item  \
#               0             Breakfast                                       Egg McMuffin
#               1             Breakfast                                  Egg White Delight
#               2             Breakfast                                   Sausage McMuffin
#               3             Breakfast                          Sausage McMuffin with Egg
#               4             Breakfast                   Sausage McMuffin with Egg Whites
#               ..                  ...                                                ...
#               255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
#               256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
#               257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
#               258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
#               259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                    Calories  TotalFat
#               0       150.0      13.0
#               1       125.0       8.0
#               2       185.0      23.0
#               3       225.0      28.0
#               4       200.0      23.0
#               ..        ...       ...
#               255     255.0      17.0
#               256     345.0      23.0
#               257     170.0      11.0
#               258     405.0      32.0
#               259     205.0      16.0
#
#               [260 rows x 4 columns]),
#              (2,
#                              Category                                               Item  \
#               0             Breakfast                                       Egg McMuffin
#               1             Breakfast                                  Egg White Delight
#               2             Breakfast                                   Sausage McMuffin
#               3             Breakfast                          Sausage McMuffin with Egg
#               4             Breakfast                   Sausage McMuffin with Egg Whites
#               ..                  ...                                                ...
#               255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
#               256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
#               257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
#               258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
#               259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                    Calories  TotalFat
#               0        75.0      13.0
#               1        62.5       8.0
#               2        92.5      23.0
#               3       112.5      28.0
#               4       100.0      23.0
#               ..        ...       ...
#               255     127.5      17.0
#               256     172.5      23.0
#               257      85.0      11.0
#               258     202.5      32.0
#               259     102.5      16.0
#
#               [260 rows x 4 columns])])

# %%
"""13. Sprawdź ile masz obiektów data frame w zmiennej final, wyświetlając jej długość"""

len(final)
# Out:
# 3

# %%
final[0]
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0         300      13.0
# 1         250       8.0
# 2         370      23.0
# 3         450      28.0
# 4         400      23.0
# ..        ...       ...
# 255       510      17.0
# 256       690      23.0
# 257       340      11.0
# 258       810      32.0
# 259       410      16.0
#
# [260 rows x 4 columns]

# %%
final[1]
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0       150.0      13.0
# 1       125.0       8.0
# 2       185.0      23.0
# 3       225.0      28.0
# 4       200.0      23.0
# ..        ...       ...
# 255     255.0      17.0
# 256     345.0      23.0
# 257     170.0      11.0
# 258     405.0      32.0
# 259     205.0      16.0
#
# [260 rows x 4 columns]

# %%
final[2]
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0        75.0      13.0
# 1        62.5       8.0
# 2        92.5      23.0
# 3       112.5      28.0
# 4       100.0      23.0
# ..        ...       ...
# 255     127.5      17.0
# 256     172.5      23.0
# 257      85.0      11.0
# 258     202.5      32.0
# 259     102.5      16.0
#
# [260 rows x 4 columns]
