# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/weather_barcelona.csv",index_col="Date")

# %%
rom = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/weather_rome.csv",index_col="Date")

# %%
ams = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/weather_amsterdam.csv",index_col="Date")

# %%
# utworz nowy dataframe z indexem z df bar
temp_max = pd.DataFrame(index = bar.index)

# %%
temp_max
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8
# ...               ...   ...        ...
# 2018-03-27         16    16         10
# 2018-03-28         20    17          8
# 2018-03-29         17    19         11
# 2018-03-30         19    20         14
# 2018-03-31         19    17         11
#
# [90 rows x 3 columns]

# %%
# do temp_max dodaj kolumne Barcelona z warosciami z df bar TempMax itd.
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']

# %%
def GradeDay(row):
    if(row['TempMax'] >= row["AvgTempMax"]):
        return 'PLUS'
    else:
        return "MINUS"

# %%
# do df rom dodaj kolumne GradeDay z wartosciami wygenerowanymi przez GradeDay dla każdego wiersza
rom['GradeDay'] = rom.apply(GradeDay, axis=1)
bar['GradeDay'] = bar.apply(GradeDay, axis=1)
ams['GradeDay'] = ams.apply(GradeDay, axis=1)

# %%
rom.head()
# Out:
#             TempMax  TempMin Rain  AvgTempMax  AvgTempMin GradeDay
# Date
# 2018-01-01       14        8   0           12           4     PLUS
# 2018-01-02       13        7   0           12           4     PLUS
# 2018-01-03       14        1   0           12           4     PLUS
# 2018-01-04       16        6   0           12           4     PLUS
# 2018-01-05       17        7   0           12           3     PLUS

# %%
rom['GradeDay'].value_counts()
# Out:
# PLUS     70
# MINUS    20
# Name: GradeDay, dtype: int64

# %%
# utwórz nowy DataFrame o nazwie cities3 z indexami o nazwie MINUS i PLUS
cities3 = pd.DataFrame(index=["MINUS","PLUS"])

# %%
# do DataFrame cities3 dodaj kolumnę Barcelona o warotściach pokazującą ilość wartości w DataFrame bar i kolumnie GradeDay 
cities3['Barcelona'] = bar['GradeDay'].value_counts()

# %%
cities3['Rome'] = bar["GradeDay"].value_counts()

# %%
cities3['Amsterdam'] = bar['GradeDay'].value_counts()

# %%
cities3
# Out:
#        Barcelona  Rome  Amsterdam
# MINUS         26    26         26
# PLUS          64    64         64

# %%
# wcześniej domyślnie była elipsa, teraz już jest koło
cities3['Barcelona'].plot(kind='pie')

# %%
# gdy wcześniej była elipsa, aby zrobić koło trzebabyło w figsize podać dwa razy tę samą wartość liczbową
cities3['Barcelona'].plot(kind='pie',figsize=(7,7))

# %%
cities3.plot(kind="pie", subplots=True, figsize=(15,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x117a9e3d0>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(15,5),colors=['b','g'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x117ba11d0>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(15,5),colors=['b','g'],labels=['colder','warmer'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x117e2db50>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(15,5),colors=['b','g'],labels=['colder','warmer'],autopct='%.0f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11800f5d0>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(15,5),colors=['b','g'],
             labels=['colder','warmer'],autopct='%.0f%%',fontsize=20)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1181f3e10>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(15,5),colors=['b','g'],
             labels=['colder','warmer'],autopct='%.0f%%',fontsize=20,textprops=dict(color='w'))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1183e4ad0>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(10,10),colors=['b','g'],labels=['colder','warmer'],
             autopct='%.0f%%',fontsize=20,textprops=dict(color='w'),layout=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1185df250>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(10,10),colors=['b','g'],labels=['colder','warmer'],
             autopct='%.0f%%',fontsize=20,textprops=dict(color='w'),layout=(2,2), explode=(1,0))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118a8ea90>,
# ...
#       dtype=object)

# %%
cities3.plot(kind="pie", subplots=True, figsize=(10,10),colors=['b','g'],labels=['colder','warmer'],
             autopct='%.0f%%',fontsize=20,textprops=dict(color='w'),layout=(2,2), explode=(0.2,0))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118e0e490>,
# ...
#       dtype=object)

# %%
# pie plot
# series.plot(kind='plot')
# df.plot(kind='plot',subplots=True)
# figsize=(x,y)
# layout=(x,y)
# labels=[...]
# autopct='%.0f%%'
# fontsize=x
# textprops=dict(...)
# explode=[...]
