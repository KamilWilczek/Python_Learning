# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/northwind-mongo-master/products.csv",
                      usecols=['ProductID','ProductName','CategoryID','UnitPrice'])

# %%
categories = pd.read_csv("/Users/kamilw/Desktop/Moje/PythonLearing/Pandas_Udemy/course-files/northwind-mongo-master/categories1.csv",
                        usecols=['CategoryID','CategoryName','Description'])

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products.merge(categories,on='CategoryID').head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice CategoryName  \
# 0          1                Chai           1       18.0    Beverages
# 1          2               Chang           1       19.0    Beverages
# 2         24  Guaraná Fantástica           1        4.5    Beverages
# 3         34       Sasquatch Ale           1       14.0    Beverages
# 4         35      Steeleye Stout           1       18.0    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
# symulacja kiedy kolumna sie zle nazywa
categories.rename({'CategoryID':'ID'}, axis='columns',inplace=True)

# %%
categories.head()
# Out:
#    ID    CategoryName              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(categories,on='CategoryID').head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-ca95f4b0616b> in <module>
# ----> 1 products.merge(categories,on='CategoryID').head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ...

# %%
products.merge(categories,on='ID').head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-d65b5ef8afe0> in <module>
# ----> 1 products.merge(categories,on='ID').head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ...

# %%
#left_on i rgiht_on
# zamiast on uzywamy left_on i right_on zeby dopasowywalo do wybranych kolumn
products.merge(categories,left_on='CategoryID',right_on='ID').head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice  ID CategoryName  \
# 0          1                Chai           1       18.0   1    Beverages
# 1          2               Chang           1       19.0   1    Beverages
# 2         24  Guaraná Fantástica           1        4.5   1    Beverages
# 3         34       Sasquatch Ale           1       14.0   1    Beverages
# 4         35      Steeleye Stout           1       18.0   1    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
# a co jeśli dwie kolumny będą miały te same nazwy?
products.rename({'ProductName':'Name'},axis='columns',inplace=True)

# %%
categories.rename({'CategoryName':'Name'},axis='columns',inplace=True)

# %%
products.merge(categories,left_on='CategoryID',right_on='ID').head()
# Out:
#    ProductID              Name_x  CategoryID  UnitPrice  ID     Name_y  \
# 0          1                Chai           1       18.0   1  Beverages
# 1          2               Chang           1       19.0   1  Beverages
# 2         24  Guaraná Fantástica           1        4.5   1  Beverages
# 3         34       Sasquatch Ale           1       14.0   1  Beverages
# 4         35      Steeleye Stout           1       18.0   1  Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
products.merge(categories,left_on='CategoryID',right_on='ID',suffixes=['_prod','_category']).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice  ID Name_category  \
# 0          1                Chai           1       18.0   1     Beverages
# 1          2               Chang           1       19.0   1     Beverages
# 2         24  Guaraná Fantástica           1        4.5   1     Beverages
# 3         34       Sasquatch Ale           1       14.0   1     Beverages
# 4         35      Steeleye Stout           1       18.0   1     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
# sort - dane będą posortowane wg klucza wg którego było wykonywane złączenie danych, how='inner' i tak sortuje
products.merge(categories,left_on='CategoryID',right_on='ID',suffixes=['_prod','_category'],sort=True).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice  ID Name_category  \
# 0          1                Chai           1       18.0   1     Beverages
# 1          2               Chang           1       19.0   1     Beverages
# 2         24  Guaraná Fantástica           1        4.5   1     Beverages
# 3         34       Sasquatch Ale           1       14.0   1     Beverages
# 4         35      Steeleye Stout           1       18.0   1     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
# złączenie wykonywane w oparciu o indeks
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
categories.set_index('ID',inplace=True)

# %%
categories.head()
# Out:
#               Name              Description
# ID
# 1        Beverages              Soft drinks
# 2       Condiments  Sweet and savory sauces
# 3      Confections                 Desserts
# 4   Dairy Products                  Cheeses
# 5   Grains/Cereals                   Breads

# %%
products.merge(categories,left_on='CategoryID',right_index=True,suffixes=['_prod','_category'],sort=True).head()
# Out:
#     ProductID           Name_prod  CategoryID  UnitPrice Name_category  \
# 0           1                Chai           1       18.0     Beverages
# 1           2               Chang           1       19.0     Beverages
# 23         24  Guaraná Fantástica           1        4.5     Beverages
# 33         34       Sasquatch Ale           1       14.0     Beverages
# 34         35      Steeleye Stout           1       18.0     Beverages
#
#     Description
# 0   Soft drinks
# 1   Soft drinks
# 23  Soft drinks
# 33  Soft drinks
# 34  Soft drinks

# %%
# using merge options
# left_on = 'column'
# right_on = 'column'
# suffixes = ['suffix_left','suffix_right']
# sort = True
# left_index = 'index_name'
# right_index = 'index_name'
